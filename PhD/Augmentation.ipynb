# %%
from PIL import Image
from PIL import ImageShow
import imageio
import os
import scipy.ndimage as nd
import numpy as np
inputs='/Users/mattvalko/Documents/PHD/'
outputs='/Users/mattvalko/Documents/PHD/output/'

filename='/Users/mattvalko/Documents/PHD/BurseraPhotos7292020/Venezuela/Bursgrav_MO_Agostini_2588.jpg'

import matplotlib.pyplot as plt

# %%
img= imageio.imread(filename)

# %%
plt.imshow(img)
plt.show()

# %%
img_90=nd.rotate(img,90)

# %%
plt.imshow()
plt.show()

# %%
img_zoom_2=nd.zoom(img,1.5)

# %%
plt.imshow(img_zoom_2)

# %%
shift_20 =nd.shift(img,(20,5,0),order=1)

# %%
plt.imshow(shift_20)

# %%
img_180=nd.rotate(img,180)

# %%
plt.imshow(img_180)

# %%
V,H,Z =img.shape
M=np.indices((V,H,Z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-e5cc4e21ebef> in <module>
#       1 V,H,Z =img.shape
# ----> 2 M=np.indices(V,H,Z)
#       3
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in indices(dimensions, dtype, sparse)
#    1736
#    1737     """
# -> 1738     dimensions = tuple(dimensions)
#    1739     N = len(dimensions)
#    1740     shape = (1,)*N
#
# TypeError: 'int' object is not iterable

# %%
d=5
q=2*d*np.random.ranf(M.shape)-d
Mp= (M+q).astype(int)
fuzz=nd.map_coordinates(img,Mp)

# %%
plt.imshow(fuzz)

# %%
V,H,Z
# Out:
# (5616, 3744, 3)

# %%
img_zoom_3=nd.zoom(img,(2,2,1.5))

# %%
plt.imshow(img_zoom_3)
